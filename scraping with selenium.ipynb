# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1848\2935088855.py:2: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True

# %%
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1848\595655326.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)

# %%
driver.get('https://www.tomsguide.com/reviews/iphone-14-pro-max')

# %%
driver.page_source
# Out:
# '<html lang="en" dir="ltr" data-locale="US" class=""><link href="//vanilla.futurecdn.net/tomsguide/623942/media/css/tomsguide.min.css" rel="stylesheet" type="text/css"><head class=""><script async="" defer="" src="//www.googletagmanager.com/gtm.js?id=GTM-KHCPGDF"></script><script async="" defer="" src="//www.googletagmanager.com/gtm.js?id=GTM-TPBZDKD"></script><script async="" src="https://sb.scorecardresearch.com/cs/10055482/beacon.js"></script><script async="" src="//cdn.taboola.com/libtrc/futureplc-network/loader.js"></script><script id="main-js" src="//vanilla.futurecdn.net/tomsguide/623942/media/shared/js/main.151fb4c407803ddab08c.bundle.js" async="1"></script><script type="text/javascript" charset="utf-8" async="" src="//ssl.p.jwpcdn.com/player/v/8.26.7/jwpsrv.js"></script><script type="text/javascript" charset="utf-8" async="" src="//ssl.p.jwpcdn.com/player/v/8.26.7/bidding.js"></script><script type="text/javascript" charset="utf-8" async="" src="//ssl.p.jwpcdn.com/player/v/8.
# ...

# %%
driver.find_elements(By.XPATH, '//article')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="5a6d7259-f2bc-4920-b47c-9e6bd0992270")>]

# %%
content = driver.find_element(By.ID, 'content-after-image')

# %%
content
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="8c997cdb-3ed9-46a3-ac0b-17b082dce56e")>

# %%
content = driver.find_element(By.ID, 'content-after-image')
content.text
# Out:
# "Tom's Guide Verdict\nThe iPhone 14 Pro Max isn’t just the most powerful phone around. It’s a joy to use, thanks to the clever new Dynamic Island for displaying notifications and live activities. Apple’s largest Pro model also delivers fantastic cameras — including a new 48MP main shooter — an always-on display, compelling Action mode for video and excellent battery life. It’s pricey, but it’s also the best phone money can buy.\nPros\n+Superb 48MP camera\n+Very smart Dynamic Island\n+Superb battery life\n+Always-on display\n+Impressive Action mode for video\nCons\n-Lack of SIM Card slot will annoy some\n-Still just 20W charging\n-A bit thicker and heavier\nWhy you can trust Tom's Guide Our expert reviewers spend hours testing and comparing products and services so you can choose the best for you. Find out more about how we test.\nThe iPhone 14 Pro Max is the iPhone I'd recommend to power users. Why? Well, you get the best cameras in a phone based on my testing, a new always-on on dis
# ...

# %%
content = driver.find_elements(By.XPATH, "//div[@class='pretty-verdict__verdict']")[0]
content.text
# Out:
# 'The iPhone 14 Pro Max isn’t just the most powerful phone around. It’s a joy to use, thanks to the clever new Dynamic Island for displaying notifications and live activities. Apple’s largest Pro model also delivers fantastic cameras — including a new 48MP main shooter — an always-on display, compelling Action mode for video and excellent battery life. It’s pricey, but it’s also the best phone money can buy.'

# %%
content = driver.find_elements(By.XPATH, "//p")
content
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="6f1a7dbb-295c-47fc-ab4e-506af93188f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="526b3a8d-8178-4d94-af3d-b9ffcea851b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="bfe56c0a-483b-47f4-bbda-cf02075068e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="b10e51be-a5d9-4157-a8df-e95a213f1589")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="bd2a85e5-7c58-4b13-bde4-bde2dc434831")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ece50aa843c7ceb74baa610ba11d0a1f", element="dcba4694-baef-4ca2-8973-3be28ca59439")>,
# ...

# %%
content[0].text
# Out:
# 'When you purchase through links on our site, we may earn an affiliate commission. Here’s how it works.'
